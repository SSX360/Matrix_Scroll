# %% [markdown]
# # Machine Learning Training
# This is a test notebook.

# %%
import numpy as np
import pandas as pd
import torch

# %%
df = pd.DataFrame({'a': [1, 2, 3]})
model = torch.nn.Linear(10, 2)
